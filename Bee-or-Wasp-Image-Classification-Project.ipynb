# %% [markdown]
# <div style="align: center; margin: 0; padding: 0; height: 250px;">
#     <br>
#     <img src="https://i.imgur.com/vawKwSJ.png" style="display:block; margin:auto; width:65%; height:100%;">
# </div><br><br>
#
# <div style="letter-spacing:normal; opacity:1.;">
# <!--   https://xkcd.com/color/rgb/   -->
#   <p style="text-align:center; background-color: lightsalmon; color: Jaguar; border-radius:10px; font-family:monospace;
#             line-height:1.4; font-size:32px; font-weight:bold; text-transform: uppercase; padding: 9px;">
#             <strong>Bee or Wasp Dataset</strong></p>
#
#   <p style="text-align:center; background-color:romance; color: Jaguar; border-radius:10px; font-family:monospace;
#             line-height:1.4; font-size:22px; font-weight:normal; text-transform: capitalize; padding: 5px;"
#      >Machine Learning Engineer Deep Learning Project:<br>Bee or Wasp Image Classification with CNN<br><br></p>
#
#   <div style="align: center;">
#   <table style="text-align: center; background-color: romance; color: Jaguar; border-radius: 10px; font-family: monospace;
#                   line-height:1.4; font-size: 21px; font-weight: normal; text-transform: capitalize; padding: 5px;
#                   margin: 0 auto;">
#     <tr><td style="text-align: left; padding-left: 0px;"
#             > Exploratory Data Analysis (EDA) <span style="font-size: 16px;">(Images)</span></td></tr>
#     <tr><td style="text-align: left; padding-left: 0px;"
#             > Convolutional Neural Network (CNN or ConvNet) <span style="font-size: 16px;">( <a href="https://www.tensorflow.org/install">Tensorflow</a>, Keras )</span></td></tr>
#     <tr><td style="text-align: left; padding-left: 0px;"
#             > Generators and Training <span style="font-size: 16px;">( ImageDataGenerator )</span></td></tr>
#     <tr><td style="text-align: left; padding-left: 0px;"
#             > Data Augmentation <span style="font-size: 16px;">( augmentations with training data generator )</span></td></tr>
#   </table>
#   </div>
#
# </div>
# <br><br>
#
# > Stanford CS: https://cs231n.github.io/

# %% [markdown]
# **Dataset More Info**
#
# > https://www.kaggle.com/datasets/jerzydziewierz/bee-vs-wasp
#
#
# **About Dataset**
#
# 19480 Hand curated photos of bees, wasps and other insects.
#
# **Synopsis**
#
# Hand-curated, close-up photos of bees, wasps, and other insects. The challenge is primarily to distinguish bees from wasps.
#
# **Excerpt from labels.csv :**
#
# ```
# id,path,is_bee,is_wasp,is_otherinsect,is_other,photo_quality,is_validation,is_final_validation
# 1,bee1\10007154554_026417cfd0_n.jpg,1,0,0,0,1,0,0
# 2,bee1\10024864894_6dc54d4b34_n.jpg,1,0,0,0,1,0,1
# 3,bee1\10092043833_7306dfd1f0_n.jpg,1,0,0,0,1,1,0
# 6842,wasp2\I00101.jpg,0,1,0,0,0,0,0
# 6843,wasp2\I00102.jpg,0,1,0,0,0,0,0
# 6844,wasp2\I00103.jpg,0,1,0,0,0,1,0
# ```
#
# **Dataset totals**
#
# ```
# we have:
#  bees..........: 3183
#  wasps.........: 4943
#  other insects.: 2453
#  other.........: 845
#
# in that, there is:
#  training photos : 7942
#  hyperparameter tuning (1st level validation) photos : 1719
#  final validation (brag about your result with these) photos : 1763
#
# In the final validation, there is 504 bees and 753 wasps, meaning that the resolution of the result is 0.08%
# ```
#
# **Labels:**
#
# in labels.csv :
#
# - `id` - ordinal - unique index
# - `path` - string - relative path to the photo, including extension
# - `is_bee` - nominal - 1 if there is a bee in the photo
# - `is_wasp` - nominal - 1 if there is a wasp in the photo
# - `is_otherinsect` - nominal - 1 if there is other insect prominently in the centre of the photo, but it is not a wasp and not a bee. It might be a fly, but there are other things there too, like beetles
# - `is_other` - random photos not containing any insects
# - `photo_quality` - 1 for photos where I have very high confidence that it is bee, wasp, or other. 0 for photos of generally low quality or where I am not very confident that it is what it says it is. You can use this to initially reduce the size of the training set
# - `is_validation` - you can use this for your training validation, or you can combine these with the training data and split your training/validation differently
# - `is_final_validation` - do NOT use these photos for training - use them to compute your final score. This will enable comparing results by different kagglers. Optionally, if you want to deploy an app to actually serve the model, you can then use these for final training too.
#
#
# ---
#
#
# **Credits**
#
# This image dataset collates and refines upon several sources:
#
# - "PollenDataset" by 2017 Ivan Rodriguez, Rémi Mégret, Edgar Acuña, José Agosto, Tugrul Giray, from https://www.kaggle.com/ivanfel/honey-bee-pollen
#
# - https://www.kaggle.com/tegwyntwmffat/european-wasp-vespula-vulgaris-kitti-format/ - there isn't any better description
#
# - Flicker search for bee, wasp and fly
#
# The photos have been hand-curated by our expert biologist, Callum Robertson https://www.linkedin.com/in/callum-robertson-358014109/
#
# Collator and Kaggle competitor: George Rey https://www.linkedin.com/in/dr-george-rey-dziewierz/
#
#
# ---
#
#
# **Contributions:**
#
# Ivan Rodriguez, Rémi Mégret, Edgar Acuña, José Agosto, Tugrul Giray. Recognition of pollen-bearing bees from Video using Convolutional Neural Network, IEEE Winter Conf. on Applications of Computer Vision, 2018, Lake Tahoe, NV. https://doi.org/10.1109/WACV.2018.00041
#
# **Inspiration**
#
# Some notes:
#
# - The data is probably biased:
#     - Most bees are photographed on a flower, while most wasps are not. Your AI might learn to recognize the existence of a flower rather than existence of a bee.existence of a bee. You might want to test it against some "empty flowers" to verify.

# %% [markdown]
# ## Homework
#
# > **Note**: sometimes your answer doesn't match one of
# > the options exactly. That's fine.
# > Select the option that's closest to your solution.
#
# ### Dataset
#
# In this homework, we'll build a model for predicting if we have an image of a bee or a wasp.
# For this, we will use the "Bee or Wasp?" dataset that was obtained from [Kaggle](https://www.kaggle.com/datasets/jerzydziewierz/bee-vs-wasp) and slightly rebuilt.
#
# You can download the dataset for this homework from [here](https://github.com/SVizor42/ML_Zoomcamp/releases/download/bee-wasp-data/data.zip):
#
# ```bash
# wget https://github.com/SVizor42/ML_Zoomcamp/releases/download/bee-wasp-data/data.zip
# unzip data.zip
# ```
#
# In the lectures we saw how to use a pre-trained neural network. In the homework, we'll train a much smaller model from scratch.
#
# > **Note:** you will need an environment with a GPU for this homework. We recommend to use [Saturn Cloud](https://bit.ly/saturn-mlzoomcamp).
# > You can also use a computer without a GPU (e.g. your laptop), but it will be slower.
#
#
# ---
#
#
# ## Submit the results
#
# - Submit your results here: https://forms.gle/5sjtM3kzY9TmLmU17
# - If your answer doesn't match options exactly, select the closest one
# - You can submit your solution multiple times. In this case, only the last submission will be used
#
#
# ## Deadline
#
# The deadline for submitting is November 20 (Monday), 23:00 CET. After that the form will be closed.
#
# Questions: https://github.com/DataTalksClub/machine-learning-zoomcamp/blob/master/cohorts/2023/08-deep-learning/homework.md

# %% [markdown]
# <div style="letter-spacing:normal; opacity:1.;">
#   <h1 style="text-align:center; background-color: lightsalmon; color: Jaguar; border-radius:10px; font-family:monospace; border-radius:20px;
#             line-height:1.4; font-size:32px; font-weight:bold; text-transform: uppercase; padding: 9px;">
#             <strong>1. Import Libraries & Ingest Data</strong></h1>
# </div>
#
# > ⚠️ Not Recommended conda `base` environment, Work on a virtual environment like: `venv`, `pipenv`, `new conda environment`
# > https://docs.conda.io/projects/conda/en/4.6.0/_downloads/52a95608c49671267e40c689e0bc00ca/conda-cheatsheet.pdf
#
#
# ```bash
# # New conda environment
# conda create --name "tf-env" python=3.10 -y
# conda activate "tf-env"
#
# # install all package dependencies with pip (fast)
# pip install -r requirements.txt
#
# # install all package dependencies with conda (slow)
# # Add required channels, If Needed
# conda config --add channels conda-forge
# conda install --file requirements.txt --update-deps
#
# # export a list of dependencies and their versions for recreation
# pip freeze > requirements.txt
# conda create --name "tf-env" --file requirements.txt
#
# # export a list of installed packages for recreation
# conda list --export > environment.yml
# conda env create --file environment.yml
# ```
#
# ```bash
# # If the environment is inconsistent, follow these steps:
#
# # Check for Conflicts in the environment
# conda list --untracked
#
# # Check the health report for any issues
# conda doctor
#
# # Update Conda package manager
# conda update conda
#
# # Update the base environment (force-reinstall)
# conda update -n "base" -c defaults conda --force-reinstall
#
# # Update all packages in the environment
# conda update --all
#
# # Reset base environment
# conda install --revision 0
#
# # Remove and recreate a specific environment (replace "tf-env" with your environment name)
# conda env remove --name "tf-env"
#
# # Reinstall the full Anaconda distribution (force-reinstall)
# conda install anaconda --force-reinstall
# ```
#
# **You must use the `--no-deps` option in the pip install command in order to avoid bundling dependencies into your conda-package.**
#
# If you run pip install without the `--no-deps` option, pip will often install dependencies in your conda recipe and those dependencies will become part of your package. This wastes space in the package and `increases the risk of file overlap`, file clobbering, and broken packages.
#
# There might be cases where you want to install a package directly from a local directory or a specific location, without relying on the package indexes. In such situations, you can use the `--no-index` option to tell pip not to look for the package in any indexes.
#
# ```bash
# # Install Jupyter Notebook Extensions using pip (try Conda Base env)
# pip install jupyter_contrib_nbextensions
# # Install Jupyter Notebook Extensions (user-specific installation)
# jupyter contrib nbextension install --user
#
# # Install Jupyter nbextensions configurator using pip
# pip install jupyter_nbextensions_configurator
# # Enable Jupyter nbextensions configurator (user-specific configuration)
# jupyter nbextensions_configurator enable --user
#
# # List installed Jupyter nbextensions
# jupyter nbextension list
#
# # Enable classic Jupyter Notebook to display and use widgets
# jupyter nbextension enable --py widgetsnbextension
# ```
#
# ```bash
# # When running commands in a command-line interface:
# - command1 & command2   # (independently) runs simultaneously in the background
# - command1 ; command2   # (sequentially)  runs regardless of whether it succeeds or fails
# - command1 && command2  # (sequentially)  runs command2 only if command1 succeeds (returns exit status 0)
# - command1 || command2  # (sequentially)  runs command2 only if command1 fails  (returns a non-zero exit status)
# ```

# %%
# !python -V
# Out:
# Python 3.9.13

# %%
# %%writefile requirements.txt
# # Basic
# numpy
# pandas
# scipy
# matplotlib
# seaborn
#
# # Progress bar
# tqdm
# ipywidgets
#
# # Deep Learning
# scikit-plot
# # CPU
# # tensorflow
# # GPU
# # tensorflow[and-cuda]
# Out:
# Overwriting requirements.txt

# %%
import os, sys, platform, IPython.display

# [Optionally] pip -q --no-deps --no-index --force-reinstall --no-cache-dir --user
# !{sys.executable} -m pip install -r requirements.txt --no-cache-dir -U
# !jupyter nbextension enable --py widgetsnbextension

# IPython.display.clear_output()
print("Platform:", platform.system())  # platform.platform()
print("Python  :", platform.python_version())  # sys.version
print("Actv Env:", os.getenv('CONDA_DEFAULT_ENV', 'Not Found Conda Env'))
# Out:
# Enabling notebook extension jupyter-js-widgets/extension...
#       - Validating: OK
# Platform: Linux
# Python  : 3.9.13
# Actv Env: saturn

# %% [markdown]
# ## Import Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns
import scipy

import os
import sys
import pickle
import zipfile
# import urllib
# import pathlib
from glob import glob
from tqdm.auto import tqdm
# tqdm._instances.clear()

# Import joblib for model persistence
# from joblib import load, dump

# memory management performs garbage collection 
import gc
gc.collect()
# Out:
# 0

# %%
import os
# Disable TensorFlow warnings, before you import tensorflow
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'

import tensorflow as tf
print("Tensorflow version \t\t:", tf.__version__)

# Determines the number of threads used by independent non-blocking operations.
# Tensorflow set number of threads to 1 for speed up in parallell function mapping.
# 0 means the system picks an appropriate number.
tf.config.threading.set_inter_op_parallelism_threads(num_threads=1)
print("Number of threads \t\t:", tf.config.threading.get_inter_op_parallelism_threads())

print("Available devices:")
# tf.config.list_physical_devices('GPU')
for i, device in enumerate(tf.config.list_logical_devices()):
    print("%d) %s" % (i, device))
# Out:
# Tensorflow version 		: 2.9.1
# Number of threads 		: 1
# Available devices:
# 0) LogicalDevice(name='/device:CPU:0', device_type='CPU')
# 1) LogicalDevice(name='/device:GPU:0', device_type='GPU')

# %%
 # check is tensorflow build with cuda
tf.test.is_built_with_cuda()
# Out:
# True

# %%
try:
    import tensorflow as tf
    # resolver = tf.distribute.cluster_resolver.TPUClusterResolver() 
    # tf.config.experimental_connect_to_cluster(resolver)
    # tf.tpu.experimental.initialize_tpu_system(resolver)
    # strategy = tf.distribute.TPUStrategy(resolver)
    tpu = tf.distribute.cluster_resolver.TPUClusterResolver.connect()
    strategy = tf.distribute.TPUStrategy(tpu)
    print('Running on TPU ', tpu.master(), len(tf.config.list_logical_devices('TPU')))
except ValueError:
    # If there's a GPU avaiable, to use the GPU, otherwise, using the CPU instead.
    gpus = tf.config.list_logical_devices('GPU')
    if len(gpus) > 1:
        strategy = tf.distribute.MirroredStrategy([gpu.name for gpu in gpus])
        print('Running on multiple GPUs ', gpus)
    elif len(gpus) == 1:
        # default strategy that works on CPU and single GPU
        strategy = tf.distribute.get_strategy()
        print('Running on single GPU ', gpus[0].name)
    else:
        # default strategy that works on CPU and single GPU
        strategy = tf.distribute.get_strategy()
        print('Running on CPU')
finally:
    print("Number of accelerators: ", strategy.num_replicas_in_sync)

# tf.config.set_soft_device_placement(True)
# tf.debugging.set_log_device_placement(True)
# Out:
# Running on single GPU  /device:GPU:0
# Number of accelerators:  1

# %%
# float32 or mixed_float16 (mixed precision: compute float16, variable float32)
# TPU is fast enough and has enough memory to use float32
# policy = tf.keras.mixed_precision.Policy('float32')
# tf.keras.mixed_precision.set_global_policy(policy)
print(f'Compute dtype : {tf.keras.mixed_precision.global_policy().compute_dtype}')
print(f'Variable dtype: {tf.keras.mixed_precision.global_policy().variable_dtype}')
# Out:
# Compute dtype : float32
# Variable dtype: float32

# %%
# Enable Just-In-Time (JIT) computation graph at runtime, just before they are executed. 
# The idea is to convert the computation graph into machine code optimized for the specific hardware it will run on.
# tf.config.optimizer.set_jit(True)

# %%
# Filter warning messages using the regular expressions
# import warnings
# warnings.simplefilter(action='ignore', category=FutureWarning)
# warnings.filterwarnings(action="ignore", message="FutureWarning: is_categorical_dtype*")
# warnings.filterwarnings(action="ignore", module="seaborn", category=FutureWarning, message='(is_categorical_dtype is deprecated)')
# warnings.filterwarnings(action="ignore", module="seaborn", category=FutureWarning, message='(use_inf_as_na option is deprecated)')

# Filter specific warning categories related to TensorFlow
# warnings.filterwarnings(action="ignore", module="tensorflow", category=Warning)
# warnings.filterwarnings(action="ignore", message=r".*model_pruner failed.*")
# warnings.filterwarnings(action="ignore", message=r".*Graph does not contain terminal node Add_20/ReadVariableOp.*")

# %%
# !pip install session_info
# import session_info
# session_info.show(html=False)

# %%
# import os
# Get the current working directory
# current_dir = os.getcwd()

# Create a new directory for storing data
# os.makedirs('./pycode', exist_ok=True)
# os.makedirs('./data', exist_ok=True)
# os.makedirs('./output', exist_ok=True)
# os.makedirs('./model', exist_ok=True)

# %% [markdown]
# <div style="letter-spacing:normal; opacity:1.;">
#   <h1 style="text-align:center; background-color: lightsalmon; color: Jaguar; border-radius:10px; font-family:monospace; border-radius:20px;
#             line-height:1.4; font-size:32px; font-weight:bold; text-transform: uppercase; padding: 9px;">
#             <strong>2. Recognizing and Understanding Data</strong></h1>
# </div>

# %% [markdown]
# ## Data Loading
#
# ### Ingest Data [wget](https://linuxways.net/centos/linux-wget-command-with-examples/) or [curl](https://daniel.haxx.se/blog/2020/09/10/store-the-curl-output-over-there/), If Needed

# %% [markdown]
# ### Dataset
#
# In this homework, we'll build a model for predicting if we have an image of a bee or a wasp.
# For this, we will use the "Bee or Wasp?" dataset that was obtained from [Kaggle](https://www.kaggle.com/datasets/jerzydziewierz/bee-vs-wasp) and slightly rebuilt.
#
# You can download the dataset for this homework from [here](https://github.com/SVizor42/ML_Zoomcamp/releases/download/bee-wasp-data/data.zip):
#
# ```bash
# wget https://github.com/SVizor42/ML_Zoomcamp/releases/download/bee-wasp-data/data.zip
# unzip data.zip
# ```
#
# In the lectures we saw how to use a pre-trained neural network. In the homework, we'll train a much smaller model from scratch.
#
# > **Note:** you will need an environment with a GPU for this homework. We recommend to use [Saturn Cloud](https://bit.ly/saturn-mlzoomcamp).
# > You can also use a computer without a GPU (e.g. your laptop), but it will be slower.

# %%
# Download the data
# !curl -Os https://github.com/SVizor42/ML_Zoomcamp/releases/download/bee-wasp-data/data.zip

# %%
# !unzip data.zip

# Download the zip file using TensorFlow
zip_url = "https://github.com/SVizor42/ML_Zoomcamp/releases/download/bee-wasp-data/data.zip"
zip_path = tf.keras.utils.get_file(
    fname="data.zip", 
    origin=zip_url, 
    extract=True, 
    cache_dir='.', 
    cache_subdir='.'
)

# Optionally, you can remove the downloaded zip file
os.remove(zip_path)
# Out:
# ...
# 117446836/117446836 [==============================] - 0s 0us/step

# %%
glob('data/*')
# Out:
# ['data/test', 'data/train']

# %% [markdown]
# ### Data Preparation
#
# The dataset contains around 2500 images of bees and around 2100 images of wasps.
#
# The dataset contains separate folders for training and test sets.

# %%
train_bee = sorted(glob('./data/train/bee/*'))
train_wasp = sorted(glob('./data/train/wasp/*'))

sample_bee = tf.keras.preprocessing.image.load_img(train_bee[0]) 
sample_wasp = tf.keras.preprocessing.image.load_img(train_wasp[0])

sample_bee, sample_wasp
# Out:
# (<PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=240x240>,
#  <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=319x213>)

# %%
display(sample_bee, sample_wasp)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=240x240>
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=319x213>

# %%
np.array(sample_bee).shape
# Out:
# (240, 240, 3)

# %%
input_shape = (299, 299, 3)

# %% [markdown]
# # Pre-trained convolutional neural networks
#
# - Imagenet dataset  : https://www.image-net.org/
# - Pre-trained models: https://keras.io/api/applications/

# %%
sample_bee = tf.keras.preprocessing.image.load_img(train_bee[0], target_size=input_shape)
sample_bee
# Out:
# <PIL.Image.Image image mode=RGB size=299x299>

# %%
model = tf.keras.applications.Xception(
    include_top=True,
    weights="imagenet",
    input_tensor=None,
    input_shape=input_shape,
    pooling=None,
    classes=1000,
    classifier_activation="softmax",
)

# %%
X = np.array([np.array(sample_bee)])
X.shape
# Out:
# (1, 299, 299, 3)

# %%
model.predict(X)
# Out:
# 1/1 [==============================] - 3s 3s/step
# array([[1.37161331e-27, 2.92515054e-35, 6.35803566e-30, 0.00000000e+00,
#         3.34535619e-36, 0.00000000e+00, 0.00000000e+00, 1.55773217e-34,
#         1.95968995e-30, 2.35294824e-25, 3.11496056e-19, 3.88571870e-28,
#         1.96991016e-18, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         2.65129791e-19, 1.50674736e-23, 0.00000000e+00, 3.29385405e-37,
#         0.00000000e+00, 1.68257445e-36, 9.04640763e-33, 4.67390773e-30,
#         4.54453597e-25, 5.69517046e-25, 1.28994097e-37, 1.44042821e-37,
#         3.97184841e-27, 0.00000000e+00, 2.61707689e-31, 2.29213714e-11,
#         2.86674466e-21, 7.63415439e-34, 3.39910722e-25, 0.00000000e+00,
#         0.00000000e+00, 4.30291675e-37, 7.97494639e-30, 8.36678675e-32,
#         3.54430995e-20, 0.00000000e+00, 2.33898372e-36, 4.47365195e-33,
#         0.00000000e+00, 1.53690344e-25, 6.13097890e-29, 2.43468551e-34,
# ...

# %%
X_scaled = tf.keras.applications.xception.preprocess_input(X)
X_scaled
# Out:
# array([[[[-0.03529412,  0.02745104,  0.05098045],
#          [-0.02745098,  0.01176476,  0.05882359],
#          [-0.05098039, -0.01960784,  0.06666672],
#          ...,
#          [ 0.09019613,  0.03529418,  0.17647064],
#          [ 0.10588241, -0.04313725,  0.11372554],
#          [ 0.15294123, -0.0745098 ,  0.09803927]],
#
#         [[ 0.00392163,  0.07450986,  0.11372554],
#          [-0.00392157,  0.05098045,  0.11372554],
#          [-0.04313725,  0.01176476,  0.09019613],
#          ...,
#          [ 0.09803927,  0.02745104,  0.17647064],
#          [ 0.082353  , -0.06666666,  0.09019613],
#          [ 0.12156868, -0.10588235,  0.06666672]],
#
#         [[-0.10588235, -0.01960784, -0.00392157],
#          [-0.05882353, -0.00392157,  0.04313731],
#          [-0.04313725,  0.01176476,  0.09019613],
#          ...,
#          [ 0.09019613, -0.00392157,  0.15294123],
#          [ 0.082353  , -0.09019607,  0.07450986],
#          [ 0.11372554, -0.12156862,  0.06666672]],
#
# ...

# %%
pred = model.predict(X_scaled)
pred
# Out:
# 1/1 [==============================] - 1s 660ms/step
# array([[4.49695654e-06, 8.63178957e-06, 1.82748918e-05, 9.97959796e-06,
#         3.58568309e-06, 4.11267638e-06, 1.01745854e-05, 1.81715914e-05,
#         9.17454418e-06, 3.93850405e-06, 5.97552571e-06, 1.73724911e-05,
#         2.44749244e-05, 6.90895558e-06, 4.60581214e-06, 4.27213672e-06,
#         4.92807658e-06, 5.78741583e-06, 4.14905344e-06, 7.17023431e-06,
#         9.71710506e-06, 8.69371615e-06, 5.40019346e-06, 5.49493643e-06,
#         7.31944738e-06, 4.20142533e-06, 3.66840550e-06, 4.18663058e-06,
#         2.67973246e-06, 5.89408137e-06, 1.20153181e-05, 7.05813454e-06,
#         5.35951312e-06, 1.32775776e-05, 3.60706417e-06, 2.02564433e-06,
#         5.99909117e-06, 3.98747306e-06, 3.46469096e-06, 1.01534242e-05,
#         3.21080324e-06, 3.70147404e-06, 1.78842629e-06, 6.92237018e-06,
#         8.15869225e-06, 4.18084528e-06, 4.17237334e-06, 5.20368121e-06,
# ...

# %%
pred.shape
# Out:
# (1, 1000)

# %%
tf.keras.applications.xception.decode_predictions(pred)
# Out:
# [[('n02206856', 'bee', 0.9817046),
#   ('n02190166', 'fly', 0.006096769),
#   ('n07730033', 'cardoon', 0.0020073904),
#   ('n11879895', 'rapeseed', 0.00046862604),
#   ('n02727426', 'apiary', 0.00039665506)]]

# %% [markdown]
# <div style="letter-spacing:normal; opacity:1.;">
#   <h1 style="text-align:center; background-color: lightsalmon; color: Jaguar; border-radius:10px; font-family:monospace; border-radius:20px;
#             line-height:1.4; font-size:32px; font-weight:bold; text-transform: uppercase; padding: 9px;">
#             <strong>Model Training</strong></h1>
# </div>

# %% [markdown]
# ## Convolutional Neural Networks
#
# - Types of layers: Convolutional and Dense
# - Convolutional Layers and Filters
# - Dense Layers

# %% [markdown]
# ### Model
#
# For this homework we will use Convolutional Neural Network (CNN). Like in the lectures, we'll use Keras.
#
# You need to develop the model with following structure:
#
# * The shape for input should be `(150, 150, 3)`
# * Next, create a convolutional layer ([`Conv2D`](https://keras.io/api/layers/convolution_layers/convolution2d/)):
#     * Use 32 filters
#     * Kernel size should be `(3, 3)` (that's the size of the filter)
#     * Use `'relu'` as activation
# * Reduce the size of the feature map with max pooling ([`MaxPooling2D`](https://keras.io/api/layers/pooling_layers/max_pooling2d/))
#     * Set the pooling size to `(2, 2)`
# * Turn the multi-dimensional result into vectors using a [`Flatten`](https://keras.io/api/layers/reshaping_layers/flatten/) layer
# * Next, add a `Dense` layer with 64 neurons and `'relu'` activation
# * Finally, create the `Dense` layer with 1 neuron - this will be the output
#     * The output layer should have an activation - use the appropriate activation for the binary classification case
#
# As optimizer use [`SGD`](https://keras.io/api/optimizers/sgd/) with the following parameters:
#
# * `SGD(lr=0.002, momentum=0.8)`
#
# For clarification about kernel size and max pooling, check [Office Hours](https://www.youtube.com/watch?v=1WRgdBTUaAc).

# %% [markdown]
# ### Question 1
#
# Since we have a binary classification problem, what is the best loss function for us?
#
# * `mean squared error`
# * `binary crossentropy`
# * `categorical crossentropy`
# * `cosine similarity`
#
# > **Note:** since we specify an activation for the output layer, we don't need to set `from_logits=True`

# %%
import tensorflow as tf

def build_model(input_shape=(150, 150, 3), num_filters=32, kernel_size=(3, 3), pool_size=(2, 2), 
                dense_units=64, output_activation='sigmoid', learning_rate=0.002, momentum=0.8):
    # Define the model
    model = tf.keras.Sequential()

    # Convolutional layer
    model.add(tf.keras.layers.Conv2D(num_filters, kernel_size, activation='relu', input_shape=input_shape))

    # Max pooling layer
    model.add(tf.keras.layers.MaxPooling2D(pool_size))

    # Flatten layer
    model.add(tf.keras.layers.Flatten())

    # Dense layer with specified number of neurons and 'relu' activation
    model.add(tf.keras.layers.Dense(dense_units, activation='relu'))

    # Output layer with 1 neuron and specified activation for binary classification
    model.add(tf.keras.layers.Dense(1, activation=output_activation))

    # Compile the model with SGD optimizer
    sgd_optimizer = tf.keras.optimizers.SGD(learning_rate=learning_rate, momentum=momentum)
    model.compile(optimizer=sgd_optimizer, loss='binary_crossentropy', metrics=['accuracy'])

    return model

# Build the model with default parameters
my_model = build_model()

# Display the model summary
my_model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  conv2d_4 (Conv2D)           (None, 148, 148, 32)      896
#
#  max_pooling2d (MaxPooling2D  (None, 74, 74, 32)       0
#  )
#
#  flatten (Flatten)           (None, 175232)            0
#
#  dense (Dense)               (None, 64)                11214912
#
#  dense_1 (Dense)             (None, 1)                 65
#
# ...
# Total params: 11,215,873
# Trainable params: 11,215,873
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### Question 2
#
# What's the number of parameters in the convolutional layer of our model? You can use the `summary` method for that.
#
# * 1
# * 65
# * 896
# * 11214912

# %%
import tensorflow as tf

def build_model(input_shape=(150, 150, 3), num_filters=32, kernel_size=(3, 3), pool_size=(2, 2), 
                dense_units=64, output_activation='sigmoid', learning_rate=0.002, momentum=0.8):
    # Input layer
    input_layer = tf.keras.layers.Input(shape=input_shape)

    # Convolutional layer
    conv_layer = tf.keras.layers.Conv2D(num_filters, kernel_size, activation='relu')(input_layer)

    # Max pooling layer
    pool_layer = tf.keras.layers.MaxPooling2D(pool_size)(conv_layer)

    # Flatten layer
    flatten_layer = tf.keras.layers.Flatten()(pool_layer)

    # Dense layer with specified number of neurons and 'relu' activation
    dense_layer = tf.keras.layers.Dense(dense_units, activation='relu')(flatten_layer)

    # Output layer with 1 neuron and specified activation for binary classification
    output_layer = tf.keras.layers.Dense(1, activation=output_activation)(dense_layer)

    # Create the model
    model = tf.keras.models.Model(inputs=input_layer, outputs=output_layer)

    # Compile the model with SGD optimizer
    sgd_optimizer = tf.keras.optimizers.SGD(learning_rate=learning_rate, momentum=momentum)
    model.compile(optimizer=sgd_optimizer, loss='binary_crossentropy', metrics=['accuracy'])

    return model

# Build the model with default parameters
my_model = build_model()

# Display the model summary
my_model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  input_2 (InputLayer)        [(None, 150, 150, 3)]     0
#
#  conv2d_5 (Conv2D)           (None, 148, 148, 32)      896
#
#  max_pooling2d_1 (MaxPooling  (None, 74, 74, 32)       0
#  2D)
#
#  flatten_1 (Flatten)         (None, 175232)            0
#
#  dense_2 (Dense)             (None, 64)                11214912
#
#  dense_3 (Dense)             (None, 1)                 65
#
# ...
# Total params: 11,215,873
# Trainable params: 11,215,873
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### Generators and Training
#
# For the next two questions, use the following data generator for both train and test sets:
#
# ```python
# ImageDataGenerator(rescale=1./255)
# ```
#
# * We don't need to do any additional pre-processing for the images.
# * When reading the data from train/test directories, check the `class_mode` parameter. Which value should it be for a binary classification problem?
# * Use `batch_size=20`
# * Use `shuffle=True` for both training and test sets.
#
# For training use `.fit()` with the following params:
#
# ```python
# model.fit(
#     train_generator,
#     epochs=10,
#     validation_data=test_generator
# )
# ```

# %%
# Data generators
train_datagen = tf.keras.preprocessing.image.ImageDataGenerator(rescale=1./255)
test_datagen = tf.keras.preprocessing.image.ImageDataGenerator(rescale=1./255)

train_generator = train_datagen.flow_from_directory(
    'data/train',
    target_size=(150, 150),
    batch_size=20,
    class_mode='binary',  # For binary classification
    shuffle=True
)

test_generator = test_datagen.flow_from_directory(
    'data/test',
    target_size=(150, 150),
    batch_size=20,
    class_mode='binary',  # For binary classification
    shuffle=True
)
# Out:
# Found 3677 images belonging to 2 classes.
# Found 918 images belonging to 2 classes.

# %%
# Model building function (using the previous function)
def build_model(input_shape=(150, 150, 3), num_filters=32, kernel_size=(3, 3), pool_size=(2, 2), 
                dense_units=64, output_activation='sigmoid', learning_rate=0.002, momentum=0.8):
    input_layer = tf.keras.layers.Input(shape=input_shape)
    conv_layer = tf.keras.layers.Conv2D(num_filters, kernel_size, activation='relu')(input_layer)
    pool_layer = tf.keras.layers.MaxPooling2D(pool_size)(conv_layer)
    flatten_layer = tf.keras.layers.Flatten()(pool_layer)
    dense_layer = tf.keras.layers.Dense(dense_units, activation='relu')(flatten_layer)
    output_layer = tf.keras.layers.Dense(1, activation=output_activation)(dense_layer)

    model = tf.keras.models.Model(inputs=input_layer, outputs=output_layer)

    sgd_optimizer = tf.keras.optimizers.SGD(learning_rate=learning_rate, momentum=momentum)
    model.compile(optimizer=sgd_optimizer, loss='binary_crossentropy', metrics=['accuracy'])

    return model

# %%
# Build the model
model = build_model()

# Training the model
history = model.fit(
    train_generator,
    epochs=10,
    validation_data=test_generator
)
# Out:
# Epoch 1/10
# 184/184 [==============================] - 10s 48ms/step - loss: 0.6816 - accuracy: 0.5635 - val_loss: 0.6322 - val_accuracy: 0.6514
# Epoch 2/10
# 184/184 [==============================] - 9s 48ms/step - loss: 0.6327 - accuracy: 0.6350 - val_loss: 0.6557 - val_accuracy: 0.5425
# Epoch 3/10
# 184/184 [==============================] - 9s 48ms/step - loss: 0.6024 - accuracy: 0.6769 - val_loss: 0.5722 - val_accuracy: 0.7048
# Epoch 4/10
# 184/184 [==============================] - 9s 47ms/step - loss: 0.5543 - accuracy: 0.7234 - val_loss: 0.5393 - val_accuracy: 0.7211
# Epoch 5/10
# 184/184 [==============================] - 9s 48ms/step - loss: 0.5217 - accuracy: 0.7493 - val_loss: 0.5457 - val_accuracy: 0.7353
# Epoch 6/10
# 184/184 [==============================] - 9s 47ms/step - loss: 0.4962 - accuracy: 0.7683 - val_loss: 0.5336 - val_accuracy: 0.7298
# Epoch 7/10
# ...

# %% [markdown]
# ### Question 3
#
# What is the median of training accuracy for all the epochs for this model?
#
# * 0.20
# * 0.40
# * 0.60
# * 0.80

# %%
# Assuming you have the training history stored in 'history' variable
train_acc_values = history.history['accuracy']

# Calculate the median
median_train_acc = np.median(train_acc_values)

print("Median of training accuracy:", median_train_acc.round(2))
# Out:
# Median of training accuracy: 0.76

# %% [markdown]
# ### Question 4
#
# What is the standard deviation of training loss for all the epochs for this model?
#
# * 0.031
# * 0.061
# * 0.091
# * 0.131

# %%
# Assuming you have the training history stored in 'history' variable
train_loss_values = history.history['loss']

# Calculate the standard deviation
std_train_loss = np.std(train_loss_values)

print("Standard deviation of training loss:", std_train_loss.round(3))
# Out:
# Standard deviation of training loss: 0.086

# %% [markdown]
# ### Data Augmentation
#
# For the next two questions, we'll generate more data using data augmentations.
#
# Add the following augmentations to your training data generator:
#
# * `rotation_range=50,`
# * `width_shift_range=0.1,`
# * `height_shift_range=0.1,`
# * `zoom_range=0.1,`
# * `horizontal_flip=True,`
# * `fill_mode='nearest'`

# %%
# Updated data generator for training with augmentations
train_datagen = tf.keras.preprocessing.image.ImageDataGenerator(
    rescale=1./255,
    rotation_range=50,
    width_shift_range=0.1,
    height_shift_range=0.1,
    zoom_range=0.1,
    horizontal_flip=True,
    fill_mode='nearest'
)

# Test data generator remains the same
test_datagen = tf.keras.preprocessing.image.ImageDataGenerator(rescale=1./255)

# Updated training data generator
train_generator = train_datagen.flow_from_directory(
    'data/train',
    target_size=(150, 150),
    batch_size=20,
    class_mode='binary',  # For binary classification
    shuffle=True
)

# Test data generator remains the same
test_generator = test_datagen.flow_from_directory(
    'data/test',
    target_size=(150, 150),
    batch_size=20,
    class_mode='binary',  # For binary classification
    shuffle=True
)
# Out:
# Found 3677 images belonging to 2 classes.
# Found 918 images belonging to 2 classes.

# %% [markdown]
# ### Question 5
#
# Let's train our model for 10 more epochs using the same code as previously.
# > **Note:** make sure you don't re-create the model - we want to continue training the model
# we already started training.
#
# What is the mean of test loss for all the epochs for the model trained with augmentations?
#
# * 0.18
# * 0.48
# * 0.78
# * 0.108

# %%
# Continue Training the model
history = model.fit(
    train_generator,
    epochs=10,
    validation_data=test_generator
)
# Out:
# Epoch 1/10
# 184/184 [==============================] - 24s 132ms/step - loss: 0.5055 - accuracy: 0.7675 - val_loss: 0.4758 - val_accuracy: 0.7745
# Epoch 2/10
# 184/184 [==============================] - 24s 132ms/step - loss: 0.5061 - accuracy: 0.7593 - val_loss: 0.4833 - val_accuracy: 0.7756
# Epoch 3/10
# 184/184 [==============================] - 24s 131ms/step - loss: 0.4839 - accuracy: 0.7721 - val_loss: 0.4628 - val_accuracy: 0.7778
# Epoch 4/10
# 184/184 [==============================] - 24s 131ms/step - loss: 0.4779 - accuracy: 0.7732 - val_loss: 0.4618 - val_accuracy: 0.7702
# Epoch 5/10
# 184/184 [==============================] - 24s 131ms/step - loss: 0.4730 - accuracy: 0.7805 - val_loss: 0.4622 - val_accuracy: 0.7930
# Epoch 6/10
# 184/184 [==============================] - 24s 132ms/step - loss: 0.4693 - accuracy: 0.7884 - val_loss: 0.5249 - val_accuracy: 0.7462
# Epoch 7/10
# ...

# %%
# Assuming you have the updated training history stored in 'history' variable
test_loss_values = history.history['val_loss']

# Calculate the mean
mean_test_loss = np.mean(test_loss_values)

print("Mean of test loss:", mean_test_loss.round(3))
# Out:
# Mean of test loss: 0.48

# %% [markdown]
# ### Question 6
#
# What's the average of test accuracy for the last 5 epochs (from 6 to 10)
# for the model trained with augmentations?
#
# * 0.38
# * 0.58
# * 0.78
# * 0.98

# %%
# Assuming you have the updated training history stored in 'history' variable
test_acc_values_last5epochs = history.history['val_accuracy'][-5:]

# Calculate the average
average_test_acc_last5epochs = np.mean(test_acc_values_last5epochs)

print("Average of test accuracy for the last 5 epochs:", average_test_acc_last5epochs.round(2))
# Out:
# Average of test accuracy for the last 5 epochs: 0.76

# %% [markdown]
# ## Eval Metric

# %%
from sklearn.metrics import classification_report
from sklearn.metrics import ConfusionMatrixDisplay

def predict_and_evaluate(model, data_generator, dataset_type):
    # Extract true labels from the generator
    y_true = data_generator.labels
    # Predictions
    predictions = model.predict(data_generator)
    # Convert predictions to binary (0 or 1)
    y_pred = (predictions >= 0.5).astype(np.int32)
    
    # Print classification report
    print(f"{dataset_type} Set Classification Report:")
    print(classification_report(y_true, y_pred))

    # Display confusion matrix    
    fig, ax = plt.subplots(1, 1, figsize=(4, 2))
    ax.grid(False); ax.set_title(f"{dataset_type} Set")
    ConfusionMatrixDisplay.from_predictions(y_true=y_true, y_pred=y_pred, ax=ax)
    plt.show()

# %%
# Make predictions and evaluate on the test set
predict_and_evaluate(model, test_generator, "Test")
predict_and_evaluate(model, train_generator, "Train")
# Out:
# 46/46 [==============================] - 2s 37ms/step
# Test Set Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.56      0.55      0.55       493
#            1       0.49      0.50      0.49       425
#
#     accuracy                           0.52       918
#    macro avg       0.52      0.52      0.52       918
# weighted avg       0.52      0.52      0.52       918
# 184/184 [==============================] - 22s 121ms/step
# Train Set Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.53      0.59      0.56      1976
#            1       0.45      0.40      0.43      1701
#
#     accuracy                           0.50      3677
#    macro avg       0.49      0.49      0.49      3677
# weighted avg       0.50      0.50      0.50      3677

# %% [markdown]
# ## plot_precision_recall

# %%
# !pip install scikit-plot -Uq
import scikitplot as skplt

y_prob_val = model.predict(test_generator)
y_prob_val = np.hstack([(1- y_prob_val), y_prob_val])

skplt.metrics.plot_precision_recall(test_generator.labels, y_prob_val)
plt.plot([0, 1],[1, 0], 'k--')
# skplt.metrics.plot_roc(y_val, y_prob_val)
plt.legend(loc='upper right')
plt.show()
# Out:
# 46/46 [==============================] - 2s 37ms/step

# %% [markdown]
# ### Save Model

# %%
# Save the model
model.save('bee_wasp_model.keras')

# %% [markdown]
# ### Load Model

# %%
# Load the model
loaded_model = tf.keras.models.load_model('bee_wasp_model.keras')

# %% [markdown]
# # sample predict

# %%
sample_bee = tf.keras.preprocessing.image.load_img(train_bee[0], target_size=(150, 150, 3))
sample_bee
# Out:
# <PIL.Image.Image image mode=RGB size=150x150>

# %%
X          = np.array([np.array(sample_bee)])
# X_scaled = tf.keras.applications.imagenet_utils.preprocess_input(X, mode='torch')
X_scaled   = tf.image.convert_image_dtype(X , dtype=tf.float32)
X_scaled.shape
# Out:
# TensorShape([1, 150, 150, 3])

# %%
y_prob = loaded_model.predict(X_scaled)
y_pred = (y_prob >= 0.5).astype(np.int32)

y_prob, y_pred
# Out:
# 1/1 [==============================] - 0s 65ms/step
# (array([[0.1998911]], dtype=float32), array([[0]], dtype=int32))

# %%
train_generator.class_indices
# Out:
# {'bee': 0, 'wasp': 1}

# %%
[k for y in y_pred for k,v in train_generator.class_indices.items() if y==v]
# Out:
# ['bee']

# %% [markdown]
# ## End of Project
